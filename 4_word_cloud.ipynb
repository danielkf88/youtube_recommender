# %%
import pandas as pd
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
# read file
df_info = pd.read_csv('data/df_info_nlp.csv')
df_caption = pd.read_csv('data/df_caption_nlp.csv')

# %%
# create wordcloud using df_info['title'] 

text = ' '.join(df_info['title'])
wordcloud = WordCloud(width = 1600, height = 800, 
                background_color ='white', 
                min_font_size = 10).generate(text)

plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 

plt.show()

# %%
# create wordcloud using df_info['description'] removing stop words

text = ' '.join(df_info['description'].dropna())
stopwords = set(STOPWORDS)
stopwords.update(["https", "co", "amp", "rt", "t", "c", "s", "m", "re", "ve", "ll", "don", 
                  "didn", "doesn", "just", "like", "know"
                    ])

wordcloud = WordCloud(width = 1600, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(text)

                
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %%
# create wordcloud using df_info['keywords'] removing stop words

# join list of keywords into a single string
text = ' '.join(df_info['keywords'].dropna().apply(lambda x: ' '.join(x.split('|'))))

# create wordcloud

wordcloud = WordCloud(width = 3200, height = 1600,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(text)


plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %%
# create wordcloud using df_caption['caption'] removing stop words
text = ' '.join(df_caption['caption'].dropna())

# remove stop words in wordcloud
stopwords = set(STOPWORDS)
stopwords.update(["https", "co", "amp", "rt", "t", "c", "s", "m", "re", "ve", "ll", "don", 
                  "didn", "doesn", "just", "know"
                    ])

wordcloud = WordCloud(width = 1600, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(text)

plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %%
# create wordcloud using df_caption['caption'] removing stop words
text = ' '.join(df_caption['caption_noun_token'].dropna())

# remove stop words in wordcloud
stopwords = set(STOPWORDS)
stopwords.update(["https", "co", "amp", "rt", "t", "c", "s", "m", "re", "ve", "ll", "don", 
                  "didn", "doesn", "just", "know"
                    ])

wordcloud = WordCloud(width = 1600, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(text)

plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()
